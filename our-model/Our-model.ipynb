# %%
# !pip uninstall cmake -y
# !pip uninstall lit -y
# !pip uninstall torch -y
# !pip uninstall torchvision -y
# !pip uninstall xformers -y
# !pip uninstall diffusers[torch] -y
# !pip uninstall transformers -y
# !pip uninstall bitsandbytes -y
# !pip uninstall decord -y
# !pip uninstall accelerate -y
# !pip uninstall tensorboard -y
# !pip uninstall modelcards -y
# !pip uninstall omegaconf -y
# !pip uninstall einops -y
# !pip uninstall imageio -y
# !pip uninstall ftfy -y
# !pip uninstall opencv-python -y
# !pip uninstall ipywidgets -y
# Out:
# WARNING: Skipping cmake as it is not installed.
# WARNING: Skipping lit as it is not installed.
# Found existing installation: torch 2.0.0
# Uninstalling torch-2.0.0:
#   Successfully uninstalled torch-2.0.0
# Found existing installation: torchvision 0.15.0
# Uninstalling torchvision-0.15.0:
#   Successfully uninstalled torchvision-0.15.0
# WARNING: Skipping xformers as it is not installed.
# WARNING: Skipping diffusers as it is not installed.
# WARNING: Skipping transformers as it is not installed.
# WARNING: Skipping bitsandbytes as it is not installed.
# WARNING: Skipping decord as it is not installed.
# WARNING: Skipping accelerate as it is not installed.
# Found existing installation: tensorboard 2.12.0
# Uninstalling tensorboard-2.12.0:
#   Successfully uninstalled tensorboard-2.12.0
# WARNING: Skipping modelcards as it is not installed.
# WARNING: Skipping omegaconf as it is not installed.
# WARNING: Skipping einops as it is not installed.
# ...

# %%
# !pip install cmake
# !pip install lit
# !pip install torch==1.12.1+cu116 torchvision==0.13.1+cu116 torchaudio==0.12.1 --extra-index-url https://download.pytorch.org/whl/cu116
# !pip install omegaconf
# !pip install diffusers[torch]==0.11.1
# !pip install transformers>=4.25.1
# !pip install einops
# !pip install decord==0.6.0
# !pip install imageio
# !pip install ftfy
# !pip install opencv-python
# !pip install ipywidgets
# !pip install tensorboard
# !pip install modelcards
# !pip install numpy
# !pip install pyre-extensions==0.0.29
# Out:
# ...
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu116
# ...

# %%
#!git clone https://github.com/facebookresearch/xformers
# Out:
# Cloning into 'xformers'...
# remote: Enumerating objects: 11070, done.
# remote: Counting objects: 100% (1421/1421), done.
# remote: Compressing objects: 100% (467/467), done.
# remote: Total 11070 (delta 979), reused 1287 (delta 938), pack-reused 9649
# Receiving objects: 100% (11070/11070), 37.22 MiB | 13.12 MiB/s, done.
# Resolving deltas: 100% (7506/7506), done.

# %%
# !git clone https://github.com/facebookresearch/xformers
# %cd /project_antwerp/Video-P2P/Video-P2P/xformers
# !pip install ninja
# !git submodule update --init --recursive
# !python setup.py develop
# Out:
# fatal: destination path 'xformers' already exists and is not an empty directory.
# /project_antwerp/Video-P2P/Video-P2P/xformers
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.0/146.0 kB 5.5 MB/s eta 0:00:00
# ...
# running develop
# /opt/conda/lib/python3.10/site-packages/setuptools/command/easy_install.py:144: EasyInstallDeprecationWarning: easy_install command is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# running egg_info
# writing xformers.egg-info/PKG-INFO
# writing dependency_links to xformers.egg-info/dependency_links.txt
# writing requirements to xformers.egg-info/requires.txt
# writing top-level names to xformers.egg-info/top_level.txt
# reading manifest file 'xformers.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# ...

# %%
#!pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.0/24.0 MB 37.4 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 39.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.3/776.3 MB 3.4 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 43.8 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 524.9/524.9 kB 71.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 61.8 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 MB 23.6 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 66.0 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.3/215.3 kB 78.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 64.4 MB/s eta 0:00:00a 0:00:01
# ...

# %% [markdown]
# Add pretrained model under data/stable-diffusion
# git clone https://huggingface.co/runwayml/stable-diffusion-v1-5
# install git-lfs in this folder: pip install git-lfs

# %%
# %cd /project_antwerp/Video-P2P/Video-P2P/data/stable-diffusion/stable-diffusion-v1-5
# !sudo apt-get update --yes
# !sudo apt-get install curl git-lfs --yes
# !git lfs install
# !git lfs pull
# %cd /project_antwerp/Video-P2P/Video-P2P
# Out:
# /project_antwerp/Video-P2P/Video-P2P/data/stable-diffusion/stable-diffusion-v1-5
# Get:1 http://archive.ubuntu.com/ubuntu jammy InRelease [270 kB]
# Get:2 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [108 kB]
# Get:6 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [869 kB]
# Get:7 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [597 kB]
# Get:8 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [904 kB]
# Get:9 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd64 Packages [39.6 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 Packages [1,792 kB]
# ...

# %%
#!conda install xformers -c xformers -y
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.11.1
#   latest version: 23.3.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.3.1
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - xformers
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     openssl-3.1.0              |       hd590300_2         2.5 MB  conda-forge
#     xformers-0.0.19            |py310_cu11.8.0_pyt2.0.0        69.2 MB  xformers
#     ------------------------------------------------------------
#                                            Total:        71.7 MB
#
# The following NEW packages will be INSTALLED:
#
# ...

# %%
import sys
print(sys.path)
# Out:
# ['/project_antwerp/Video-P2P/Video-P2P', '/opt/conda/lib/python310.zip', '/opt/conda/lib/python3.10', '/opt/conda/lib/python3.10/lib-dynload', '', '/opt/conda/lib/python3.10/site-packages']

# %% [markdown]
# # Stage 1: Tuning to do model initialization.

# %%
# %cd /project_antwerp/Video-P2P/Video-P2P
# Out:
# /project_antwerp/Video-P2P/Video-P2P

# %% [markdown]
# Example data

# %%
# %cd /project_antwerp/Video-P2P/Video-P2P/data/rabbit
# !rm -rf .ipynb_checkpoints
# %cd /project_antwerp/Video-P2P/Video-P2P
# You can minimize the tuning epochs to speed up.
# !python run_tuning.py --config="configs/rabbit-jump-tune.yaml"
# Out:
# /project_antwerp/Video-P2P/Video-P2P/data/rabbit
# /project_antwerp/Video-P2P/Video-P2P
# 05/01/2023 08:12:32 - INFO - __main__ - Distributed environment: NO
# Num processes: 1
# Process index: 0
# Local process index: 0
# Device: cuda
#
# Mixed precision type: fp16
#
# {'prediction_type', 'variance_type'} was not found in config. Values will be initialized to default values.
# {'resnet_time_scale_shift', 'num_class_embeds', 'dual_cross_attention', 'class_embed_type', 'mid_block_type', 'use_linear_projection', 'upcast_attention', 'only_cross_attention'} was not found in config. Values will be initialized to default values.
# {'prediction_type'} was not found in config. Values will be initialized to default values.
# {'prediction_type'} was not found in config. Values will be initialized to default values.
# 05/01/2023 08:12:51 - INFO - __main__ - ***** Running training *****
# 05/01/2023 08:12:51 - INFO - __main__ -   Num examples = 1
# ...

# %% [markdown]
# Our data

# %%
# %cd /project_antwerp/Video-P2P/Video-P2P/data/blender
# !rm -rf .ipynb_checkpoints
# %cd /project_antwerp/Video-P2P/Video-P2P
# You can minimize the tuning epochs to speed up.
# !python run_tuning.py --config="configs/blender-ride-tune.yaml"
# Out:
# /project_antwerp/Video-P2P/Video-P2P/data/blender
# /project_antwerp/Video-P2P/Video-P2P
# 05/23/2023 16:31:07 - INFO - __main__ - Distributed environment: NO
# Num processes: 1
# Process index: 0
# Local process index: 0
# Device: cuda
#
# Mixed precision type: fp16
#
# {'variance_type', 'prediction_type'} was not found in config. Values will be initialized to default values.
# {'upcast_attention', 'resnet_time_scale_shift', 'mid_block_type', 'class_embed_type', 'num_class_embeds', 'use_linear_projection', 'dual_cross_attention', 'only_cross_attention'} was not found in config. Values will be initialized to default values.
# {'prediction_type'} was not found in config. Values will be initialized to default values.
# {'prediction_type'} was not found in config. Values will be initialized to default values.
# 05/23/2023 16:33:51 - INFO - __main__ - ***** Running training *****
# 05/23/2023 16:33:51 - INFO - __main__ -   Num examples = 1
# ...

# %% [markdown]
# Run this one

# %%
# %cd /project_antwerp/Video-P2P/Video-P2P/data/blender
# !rm -rf .ipynb_checkpoints
# %cd /project_antwerp/Video-P2P/Video-P2P
# You can minimize the tuning epochs to speed up.
# !python run_tuning.py --config="configs/blender-ride-test-tune.yaml"
# Out:
# /project_antwerp/Video-P2P/Video-P2P/data/blender
# /project_antwerp/Video-P2P/Video-P2P
# 05/23/2023 20:27:05 - INFO - __main__ - Distributed environment: NO
# Num processes: 1
# Process index: 0
# Local process index: 0
# Device: cuda
#
# Mixed precision type: fp16
#
# {'variance_type', 'prediction_type'} was not found in config. Values will be initialized to default values.
# {'upcast_attention', 'only_cross_attention', 'class_embed_type', 'use_linear_projection', 'mid_block_type', 'num_class_embeds', 'dual_cross_attention', 'resnet_time_scale_shift'} was not found in config. Values will be initialized to default values.

# %% [markdown]
# # Stage 2: Attention Control

# %% [markdown]
# Example data

# %%
# We develop a faster mode (1 min on V100):
#python run_videop2p.py --config="configs/rabbit-jump-p2p.yaml" --fast

# The official mode (10 mins on V100, more stable):
# !python run_videop2p.py --config="configs/rabbit-jump-p2p.yaml"
# Out:
# DDIM inversion...
# Null-text optimization...
# Start Video-P2P!
# 100%|███████████████████████████████████████████| 50/50 [01:00<00:00,  1.22s/it]

# %%
Our data

# %%
# We develop a faster mode (1 min on V100):
#python run_videop2p.py --config="configs/rabbit-jump-p2p.yaml" --fast

# The official mode (10 mins on V100, more stable):
# !python run_videop2p.py --config="configs/blender-ride-p2p.yaml"
# Out:
# check:  (512, 1696, 3)
# check:  (512, 1696, 3)
# check:  (512, 1696, 3)
# check:  (512, 1696, 3)
# check:  (512, 1696, 3)
# check:  (512, 1696, 3)
# check:  (512, 1696, 3)
# check:  (512, 1696, 3)
# DDIM inversion...
# (8, 512, 1696, 3)
# Null-text optimization...
# Start Video-P2P!
# timesteps: 50
# 100%|███████████████████████████████████████████| 50/50 [05:03<00:00,  6.07s/it]

# %% [markdown]
# Run this one

# %%
# %cd /project_antwerp/Video-P2P/Video-P2P/data/blender-test
# !rm -rf .ipynb_checkpoints
# %cd /project_antwerp/Video-P2P/Video-P2P/data/blender-test/masks
# !rm -rf .ipynb_checkpoints
# %cd /project_antwerp/Video-P2P/Video-P2P

# We develop a faster mode (1 min on V100):
#python run_videop2p.py --config="configs/rabbit-jump-p2p.yaml" --fast

# The official mode (10 mins on V100, more stable):
# !python run_videop2p.py --config="configs/blender-ride-test-p2p.yaml"
# Out:
# /project_antwerp/Video-P2P/Video-P2P/data/blender-test
# /project_antwerp/Video-P2P/Video-P2P/data/blender-test/masks
# /project_antwerp/Video-P2P/Video-P2P
# check:  (512, 1696, 3)
# check:  (512, 1696, 3)
# check:  (512, 1696, 3)
# check:  (512, 1696, 3)
# check:  (512, 1696, 3)
# check:  (512, 1696, 3)
# check:  (512, 1696, 3)
# check:  (512, 1696, 3)
# DDIM inversion...
# (8, 512, 1696, 3)
# Null-text optimization...
# Start Video-P2P!
# timesteps: 50
#   2%|▉                                           | 1/50 [00:06<04:54,  6.01s/it]doing update based on reference image
# in get low pass operator
# in get low pass operator
# in get low pass operator
# in get low pass operator
# in get low pass operator
# in get low pass operator
# in get low pass operator
# in get low pass operator
# in get low pass operator
# in get low pass operator
# in get low pass operator
# in get low pass operator
# in get low pass operator
# in get low pass operator
# in get low pass operator
# ...
